# %% [markdown]
# # Semantic Kernel
#
# In this code sample, you will use the [Semantic Kernel](https://aka.ms/ai-agents-beginners/semantic-kernel) AI Framework to create a simple agent.
#
# The purpose of this sample is to demonstrate the steps that will later be applied in additional code samples when implementing various agentic patterns.

# %%
# %pip install semantic-kernel==1.28.0 -q

# %% [markdown]
# ## Import the Needed Python Packages

# %%
import json
import os 

from typing import Annotated

from dotenv import load_dotenv

from IPython.display import display, HTML

from openai import AsyncOpenAI

from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.contents import FunctionCallContent, FunctionResultContent, StreamingTextContent
from semantic_kernel.functions import kernel_function

# %% [markdown]
# ## Creating the Client
#
# In this example, we will use [GitHub Models](https://aka.ms/ai-agents-beginners/github-models) to access the LLM.
#
# The `ai_model_id` is set to `gpt-4o-mini`. Try switching the model to another one available in the GitHub Models marketplace to observe different results.
#
# To use the `Azure Inference SDK` required for the `base_url` for GitHub Models, we will utilize the `OpenAIChatCompletion` connector within Semantic Kernel. There are also other [available connectors](https://learn.microsoft.com/semantic-kernel/concepts/ai-services/chat-completion) that allow you to use Semantic Kernel with other model providers.

# %%
import random   

# Define a sample plugin for the sample

class DestinationsPlugin:
    """A List of Random Destinations for a vacation."""

    def __init__(self):
        # List of vacation destinations
        self.destinations = [
            "Berlin, Germany",
            "New York, USA",
            "Cairo, Egypt",
            "Amsterdam, Netherlands",
            "Athens, Greece",
            "Milan, Italy"
        ]
        # Track last destination to avoid repeats
        self.last_destination = None

    @kernel_function(description="Provides a random vacation destination.")
    def get_random_destination(self) -> Annotated[str, "Returns a random vacation destination."]:
        # Get available destinations (excluding last one if possible)
        available_destinations = self.destinations.copy()
        if self.last_destination and len(available_destinations) > 1:
            available_destinations.remove(self.last_destination)

        # Select a random destination
        destination = random.choice(available_destinations)

        # Update the last destination
        self.last_destination = destination

        return destination

# %%
plugin = DestinationsPlugin()

first_destination = plugin.get_random_destination()
second_destination = plugin.get_random_destination()

print("First destination:", first_destination)
print("Second destination:", second_destination)

assert first_destination in plugin.destinations
assert second_destination in plugin.destinations
assert first_destination != second_destination

print("DestinationsPlugin test passed.")

# %%
load_dotenv(override=True)
client = AsyncOpenAI(
    api_key=os.environ.get("GITHUB_TOKEN"), 
    base_url=os.environ.get("GITHUB_ENDPOINT", "https://models.github.ai/inference"),
)

# Create an AI Service that will be used by the `ChatCompletionAgent`
chat_completion_service = OpenAIChatCompletion(
    ai_model_id=os.environ.get("GITHUB_MODEL_ID", "gpt-4o-mini"),
    async_client=client,
)

# %% [markdown]
# ## Creating the Agent
#
# Here, we create the Agent named `TravelAgent`.
#
# In this example, we use very basic instructions. Feel free to modify these instructions to observe how the agent's behavior changes.

# %%
agent = ChatCompletionAgent(
    service=chat_completion_service, 
    plugins=[DestinationsPlugin()],
    name="TravelAgent",
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations",
)

# %% [markdown]
# ## Running the Agents
#
# Now we can execute the Agent by setting up the `ChatHistory` and including the `system_message` within it. We'll use the `AGENT_INSTRUCTIONS` that we established earlier.
#
# Once these are set up, we create `user_inputs`, which represent what the user is sending to the agent. In this example, the message is set to `Plan me a sunny vacation`.
#
# You can modify this message to observe how the agent reacts differently.

# %%
user_inputs = [
    "Plan me a day trip.",
    "I don't like that destination. Plan me another vacation.",
]

async def main():
    thread: ChatHistoryAgentThread | None = None

    for user_input in user_inputs:
        html_output = (
            f"<div style='margin-bottom:10px'>"
            f"<div style='font-weight:bold'>User:</div>"
            f"<div style='margin-left:20px'>{user_input}</div></div>"
        )

        agent_name = None
        full_response: list[str] = []
        function_calls: list[str] = []

        # Buffer to reconstruct streaming function call
        current_function_name = None
        argument_buffer = ""

        async for response in agent.invoke_stream(
            messages=user_input,
            thread=thread,
        ):
            thread = response.thread
            agent_name = response.name
            content_items = list(response.items)

            for item in content_items:
                if isinstance(item, FunctionCallContent):
                    if item.function_name:
                        current_function_name = item.function_name

                    # Accumulate arguments (streamed in chunks)
                    if isinstance(item.arguments, str):
                        argument_buffer += item.arguments
                elif isinstance(item, FunctionResultContent):
                    # Finalize any pending function call before showing result
                    if current_function_name:
                        formatted_args = argument_buffer.strip()
                        try:
                            parsed_args = json.loads(formatted_args)
                            formatted_args = json.dumps(parsed_args)
                        except Exception:
                            pass  # leave as raw string

                        function_calls.append(f"Calling function: {current_function_name}({formatted_args})")
                        current_function_name = None
                        argument_buffer = ""

                    function_calls.append(f"\nFunction Result:\n\n{item.result}")
                elif isinstance(item, StreamingTextContent) and item.text:
                    full_response.append(item.text)

        if function_calls:
            html_output += (
                "<div style='margin-bottom:10px'>"
                "<details>"
                "<summary style='cursor:pointer; font-weight:bold; color:#0066cc;'>Function Calls (click to expand)</summary>"
                "<div style='margin:10px; padding:10px; background-color:#f8f8f8; "
                "border:1px solid #ddd; border-radius:4px; white-space:pre-wrap; font-size:14px; color:#333;'>"
                f"{chr(10).join(function_calls)}"
                "</div></details></div>"
            )

        html_output += (
            "<div style='margin-bottom:20px'>"
            f"<div style='font-weight:bold'>{agent_name or 'Assistant'}:</div>"
            f"<div style='margin-left:20px; white-space:pre-wrap'>{''.join(full_response)}</div></div><hr>"
        )

        display(HTML(html_output))

await main()
# Out:
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>Plan me a day trip.</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>TravelAgent:</div><div style='margin-left:20px; white-space:pre-wrap'>I suggest a day trip to Tokyo, Japan! Here’s a sample itinerary for your day:
#
# ### Morning:
# - **Senso-ji Temple**: Start your day at Tokyo's oldest temple located in Asakusa. Explore the temple grounds and the vibrant Nakamise shopping street.
#
# ### Mid-Morning:
# - **Tsukiji Outer Market**: Head to the Tsukiji Outer Market for some fresh seafood and delicious street food. Try some sushi and local snacks!
#
# ### Afternoon:
# - **Shibuya Crossing**: After lunch, visit the iconic Shibuya Crossing. Experience the hustle and bustle of one of the busiest pedestrian intersections in the world.
#
# - **Hachiko Statue**: Take a quick photo with the famous Hachiko Statue, a tribute to the loyal dog.
#
# ### Late Afternoon:
# - **Harajuku**: Stroll through Harajuku and check out the unique fashion and trendy shops on Takeshita Street.
#
# - **Meiji Shrine**: Visit the peaceful Meiji Shrine located nearby, surrounded by a beautiful forested area.
#
# ### Evening:
# - **Tokyo Tower**: Head to Tokyo Tower for sunset views. You can go up to the observation deck for panoramic views of the city.
#
# ### Dinner:
# - **Roppongi**: End your day in Roppongi, known for its vibrant nightlife. Choose from a variety of restaurants for dinner, perhaps trying some izakaya-style dining.
#
# ### Optional Night Activity:
# - **Shinjuku**: If you have energy left, take a trip to Shinjuku for bars and entertainment options.
#
# Don’t forget to check public transportation schedules to make the most of your time. Enjoy your day in Tokyo!</div></div><hr>
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>I don't like that destination. Plan me another vacation.</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>TravelAgent:</div><div style='margin-left:20px; white-space:pre-wrap'>How about a day trip to Sydney, Australia? Here's a sample itinerary for you:
#
# ### Morning:
# - **Sydney Opera House**: Start your day with a visit to the iconic Sydney Opera House. You can take a guided tour to learn about its history and architecture.
#
# - **Royal Botanic Garden**: After exploring the Opera House, take a stroll through the beautiful Royal Botanic Garden, which offers stunning views of Sydney Harbour.
#
# ### Late Morning:
# - **The Rocks**: Wander around The Rocks, a historic area with cobblestone streets, markets, and unique shops. You might find some interesting local crafts and souvenirs.
#
# ### Lunch:
# - **Harbour Foreshore**: Have lunch at one of the many waterfront restaurants at Circular Quay or enjoy a casual meal at a café in The Rocks.
#
# ### Afternoon:
# - **Sydney Harbour Bridge**: After lunch, take a walk across the Sydney Harbour Bridge for breathtaking views of the city and water.
#
# - **Darling Harbour**: Head to Darling Harbour, where you can explore attractions like the SEA LIFE Sydney Aquarium or simply relax by the water.
#
# ### Evening:
# - **Bondi Beach**: In the late afternoon, make your way to Bondi Beach. Enjoy the sun, take a dip, or relax on the sand.
#
# ### Dinner:
# - **Bondi Icebergs Club**: Cap off your day with dinner at Bondi Icebergs Club, where you can enjoy delicious food with a view of the beach.
#
# ### Optional Night Activity:
# - **Sydney Nightlife**: If you have some energy left, explore Sydney's nightlife in areas like Kings Cross or Newtown, which offer vibrant bars and live music venues.
#
# Hope you enjoy your day in Sydney! Let me know if you would like more information.</div></div><hr>
